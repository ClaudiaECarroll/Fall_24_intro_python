# %% [markdown]
# ## **Demo 1: Hello World**
# ```

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = "Claudia"

# %%
age = "31"

# %%
print(name, "is", age, "years old")
# Out:
# Claudia is 31 years old

# %%
print(last_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a637c5453549> in <cell line: 1>()
# ----> 1 print(last_name)
#
# NameError: name 'last_name' is not defined

# %%
print(last name)
# Out:
#   File "<ipython-input-6-04b152c056fa>", line 1
#     print(last name)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
type(age)
# Out:
# str

# %%
type(name)
# Out:
# str

# %%
new_age = 55

# %%
age = new_age

# %%
print(age)
# Out:
# 55

# %%
name = input("What is your name? ")
print("Hello", name)
# Out:
# What is your name? Claudia
# Hello Claudia

# %% [markdown]
# Exercise 1

# %% [markdown]
# ## **Demo 2: Operators, Indices and Slices**

# %%
3 + 5
# Out:
# 8

# %%
12 - 10
# Out:
# 2

# %%
2 * 10
# Out:
# 20

# %%
15 / 3
# Out:
# 5.0

# %%
# Modulus (remainder):
15 % 4
# Out:
# 3

# %%
3 ** 2
# Out:
# 9

# %%
15 // 7
# Out:
# 2

# %%
3+9*2
# Out:
# 21

# %%
# Math with variables

age = 32

future_age = age + 5

print(future_age)
# Out:
# 37

# %%
# Updating variables with operators

price = 7

price = price + 2

print(price)
# Out:
# 9

# %%
# Concatenating strings with operators

full_name = "James " + "Walsh"

print(full_name)
# Out:
# James Walsh

# %%
# Converting variable types

num = "2"
type(num)
# Out:
# str

# %%
x = int(num)
type(x)
# Out:
# int

# %%
print(x)
# Out:
# 2

# %%
y = str(x)
type(y)
# Out:
# str

# %%
a = float("12.0")
type(a)
# Out:
# float

# %%
len(name)
# Out:
# 7

# %%
# Indices

#print(name[0])

print(name[-1])
# Out:
# a

# %%
# Slices

print(name[0:3])
# Out:
# Cla

# %%
# Lists

departments = ["music", "philosophy", "chemistry"]

# %%
len(departments)
# Out:
# 3

# %%
print(departments[1])
# Out:
# philosophy

# %%
departments_2 = departments + ["computer science"]

print(departments_2)
# Out:
# ['music', 'philosophy', 'chemistry', 'computer science']

# %% [markdown]
# Exercise 2
